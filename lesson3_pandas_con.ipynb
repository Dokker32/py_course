# %% [markdown]
# Этап #1 - визуализация Matplotlib

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,10,50)
y = x
plt.plot(x, y)

# %%
x = np.linspace(0,10,50)
y = x
plt.plot(x, y)
plt.title('Линейная зависимость y = x') #заголовок
plt.xlabel('x') # название оси абсцисс
plt.ylabel('y') #название оси ординат
plt.grid() #включение отображение сетки

# %%
x = np.linspace(-10, 10)
y = [i**2 for i in x]
plt.plot(x, y)
plt.title('Парабола y = x^2') #заголовок
plt.xlabel('x') # название оси абсцисс
plt.ylabel('y') #название оси ординат
plt.grid() #включение отображение сетки

# %%
fruits = ['apple', 'peach', 'orange', 'bannana', 'melon']
counts = [34, 25, 43, 31, 17]
plt.bar(fruits, counts)
plt.title('Fruits!')
plt.xlabel('Fruit')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Этап #2 - расчет базовых метрик

# %%
data = [{'city':'new-york', 'code':1111, 'recv':197, 'send':0},
{'city':'new-york', 'code':2222, 'recv':675, 'send':0},
{'city':'new-york', 'code':3333, 'recv':189, 'send':0},
{'city':'amsterdam', 'code':4444, 'recv':235, 'send':26},
{'city':'amsterdam', 'code':5555, 'recv':959, 'send':8}]
df = pd.DataFrame(data)
df
# Out:
#         city  code  recv  send
# 0   new-york  1111   197     0
# 1   new-york  2222   675     0
# 2   new-york  3333   189     0
# 3  amsterdam  4444   235    26
# 4  amsterdam  5555   959     8

# %%
_sum = df.groupby('city')['code'].sum()
_sum
# Out:
# city
# amsterdam    9999
# new-york     6666
# Name: code, dtype: int64

# %%
_recv = df.sort_values(by = 'recv')
_recv
# Out:
#         city  code  recv  send
# 2   new-york  3333   189     0
# 0   new-york  1111   197     0
# 3  amsterdam  4444   235    26
# 1   new-york  2222   675     0
# 4  amsterdam  5555   959     8

# %%
_query = df.query('code < 4000 & send == 0')
_query
# Out:
#        city  code  recv  send
# 0  new-york  1111   197     0
# 1  new-york  2222   675     0
# 2  new-york  3333   189     0

# %% [markdown]
# Этап #3 - объединение нескольких
# Dataframe

# %%
df_1 = pd.DataFrame( [
 ['Somu', 68, 84, 78, 96],
 ['Kiku', 74, 56, 88, 85],
 ['Ajit', 77, 73, 82, 87]],
 columns=['name', 'physics', 'chemistry','algebra','calculus'])
df_1
# Out:
#    name  physics  chemistry  algebra  calculus
# 0  Somu       68         84       78        96
# 1  Kiku       74         56       88        85
# 2  Ajit       77         73       82        87

# %%
df_2 = pd.DataFrame( [
 ['Amol', 72, 67, 91, 83],
 ['Lini', 78, 69, 87, 92]],
 columns=['name', 'physics', 'chemistry','algebra','calculus'])
df_2
# Out:
#    name  physics  chemistry  algebra  calculus
# 0  Amol       72         67       91        83
# 1  Lini       78         69       87        92

# %%
df = pd.concat([df_1, df_2])
df
# Out:
#    name  physics  chemistry  algebra  calculus
# 0  Somu       68         84       78        96
# 1  Kiku       74         56       88        85
# 2  Ajit       77         73       82        87
# 0  Amol       72         67       91        83
# 1  Lini       78         69       87        92

# %%
df.reset_index(drop=True, inplace=True)
df
# Out:
#    name  physics  chemistry  algebra  calculus
# 0  Somu       68         84       78        96
# 1  Kiku       74         56       88        85
# 2  Ajit       77         73       82        87
# 3  Amol       72         67       91        83
# 4  Lini       78         69       87        92

# %% [markdown]
# Задачи:
# 1. Вывести график вида y = 1 / x (гипербола)<br/>
# 2. В файле word дана таблица. Нужно создать <br/>
# такую таблицу на python и вывести только <br/>
# те значения (можно воспользоваться <br/>
# запросами query), где номер офиса меньше <br/>
# 350, а количество сотрудников больше <br/>
# 700 человек.<br/>
